# %%
from binftools import FastaReader

# %%
FastaReader()
# Out:
# Input filename: salmo
# '...'

# %%
from binftools import FastaSlicer

# %%
salmo = FastaReader()
# Out:
# Input filename: salmo

# %%
salmosequence = FastaSlicer(salmo, 200, 900)
# Out:
# Write to file?

# %%
salmosequence = FastaSlicer(salmo, 10, 40)
# Out:
# Write to file?
